# %% [markdown]
# <a href="https://colab.research.google.com/github/bosco2508/Disease_Prediction/blob/main/Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
import seaborn as sns

# %%
df = pd.read_csv('/content/dataset2.csv')
df.head()
# Out:
#             Disease   Symptom_1  ... Symptom_16 Symptom_17
# 0  Fungal infection     itching  ...        NaN        NaN
# 1  Fungal infection   skin_rash  ...        NaN        NaN
# 2  Fungal infection     itching  ...        NaN        NaN
# 3  Fungal infection     itching  ...        NaN        NaN
# 4  Fungal infection     itching  ...        NaN        NaN
#
# [5 rows x 18 columns]

# %%
df.describe()
# Out:
#              Disease  Symptom_1  ...        Symptom_16    Symptom_17
# count           5040       5040  ...               192            72
# unique            42         36  ...                 3             1
# top     Hypoglycemia   vomiting  ...   blood_in_sputum   muscle_pain
# freq             120        822  ...                72            72
#
# [4 rows x 18 columns]

# %%
df.isna().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1326
# Symptom_6     2035
# Symptom_7     2751
# Symptom_8     3075
# Symptom_9     3327
# Symptom_10    3528
# Symptom_11    3846
# Symptom_12    4296
# Symptom_13    4536
# Symptom_14    4734
# Symptom_15    4800
# Symptom_16    4848
# Symptom_17    4968
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1326
# Symptom_6     2035
# Symptom_7     2751
# Symptom_8     3075
# Symptom_9     3327
# Symptom_10    3528
# Symptom_11    3846
# Symptom_12    4296
# Symptom_13    4536
# Symptom_14    4734
# Symptom_15    4800
# Symptom_16    4848
# Symptom_17    4968
# dtype: int64

# %%
cols = df.columns
data = df[cols].values.flatten()

s = pd.Series(data)
s = s.str.strip()
s = s.values.reshape(df.shape)

df = pd.DataFrame(s, columns=df.columns)
df.head()
# Out:
#             Disease  Symptom_1  ... Symptom_16 Symptom_17
# 0  Fungal infection    itching  ...        NaN        NaN
# 1  Fungal infection  skin_rash  ...        NaN        NaN
# 2  Fungal infection    itching  ...        NaN        NaN
# 3  Fungal infection    itching  ...        NaN        NaN
# 4  Fungal infection    itching  ...        NaN        NaN
#
# [5 rows x 18 columns]

# %%
df = df.fillna(0)
df.head()
# Out:
#             Disease  Symptom_1  ... Symptom_16 Symptom_17
# 0  Fungal infection    itching  ...          0          0
# 1  Fungal infection  skin_rash  ...          0          0
# 2  Fungal infection    itching  ...          0          0
# 3  Fungal infection    itching  ...          0          0
# 4  Fungal infection    itching  ...          0          0
#
# [5 rows x 18 columns]

# %%
df1 = pd.read_csv('/content/Symptom-severity_WithCorona.csv')
df1.head()
# Out:
#                 Symptom  weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %%
df1['Symptom'].unique()
# Out:
# array(['itching', 'skin_rash', 'nodal_skin_eruptions',
#        'continuous_sneezing', 'shivering', 'chills', 'joint_pain',
#        'stomach_pain', 'acidity', 'ulcers_on_tongue', 'muscle_wasting',
#        'vomiting', 'burning_micturition', 'spotting_urination', 'fatigue',
#        'weight_gain', 'anxiety', 'cold_hands_and_feets', 'mood_swings',
#        'weight_loss', 'restlessness', 'lethargy', 'patches_in_throat',
#        'irregular_sugar_level', 'cough', 'high_fever', 'sunken_eyes',
#        'breathlessness', 'sweating', 'dehydration', 'indigestion',
#        'headache', 'yellowish_skin', 'dark_urine', 'nausea',
#        'loss_of_appetite', 'pain_behind_the_eyes', 'back_pain',
#        'constipation', 'abdominal_pain', 'diarrhoea', 'mild_fever',
#        'yellow_urine', 'yellowing_of_eyes', 'acute_liver_failure',
#        'fluid_overload', 'swelling_of_stomach', 'swelled_lymph_nodes',
#        'malaise', 'blurred_and_distorted_vision', 'phlegm',
#        'throat_irritation', 'redness_of_eyes', 'sinus_pressure',
#        'runny_nose', 'congestion', 'chest_pain', 'weakness_in_limbs',
#        'fast_heart_rate', 'pain_during_bowel_movements',
#        'pain_in_anal_region', 'bloody_stool', 'irritation_in_anus',
#        'neck_pain', 'dizziness', 'cramps', 'bruising', 'obesity',
#        'swollen_legs', 'swollen_blood_vessels', 'puffy_face_and_eyes',
#        'enlarged_thyroid', 'brittle_nails', 'swollen_extremeties',
#        'excessive_hunger', 'extra_marital_contacts',
#        'drying_and_tingling_lips', 'slurred_speech', 'knee_pain',
#        'hip_joint_pain', 'muscle_weakness', 'stiff_neck',
#        'swelling_joints', 'movement_stiffness', 'spinning_movements',
#        'loss_of_balance', 'unsteadiness', 'weakness_of_one_body_side',
#        'loss_of_smell', 'bladder_discomfort', 'foul_smell_ofurine',
#        'continuous_feel_of_urine', 'passage_of_gases', 'internal_itching',
#        'toxic_look_(typhos)', 'depression', 'irritability', 'muscle_pain',
#        'altered_sensorium', 'red_spots_over_body', 'belly_pain',
#        'abnormal_menstruation', 'dischromic_patches',
#        'watering_from_eyes', 'increased_appetite', 'polyuria',
#        'family_history', 'mucoid_sputum', 'rusty_sputum',
#        'lack_of_concentration', 'visual_disturbances',
#        'receiving_blood_transfusion', 'receiving_unsterile_injections',
#        'coma', 'stomach_bleeding', 'distention_of_abdomen',
#        'history_of_alcohol_consumption', 'blood_in_sputum',
#        'prominent_veins_on_calf', 'palpitations', 'painful_walking',
#        'pus_filled_pimples', 'blackheads', 'scurring', 'skin_peeling',
#        'silver_like_dusting', 'small_dents_in_nails',
#        'inflammatory_nails', 'blister', 'red_sore_around_nose',
#        'yellow_crust_ooze', 'prognosis', 'sore_throat', 'tiredness'],
#       dtype=object)

# %%
vals = df.values
symptoms = df1['Symptom'].unique()
for i in range(len(symptoms)):
    vals[vals == symptoms[i]] = df1[df1['Symptom'] == symptoms[i]]['weight'].values[0]
    
d = pd.DataFrame(vals, columns=cols)
d.head()
# Out:
#             Disease Symptom_1 Symptom_2  ... Symptom_15 Symptom_16 Symptom_17
# 0  Fungal infection         1         3  ...          0          0          0
# 1  Fungal infection         3         4  ...          0          0          0
# 2  Fungal infection         1         4  ...          0          0          0
# 3  Fungal infection         1         3  ...          0          0          0
# 4  Fungal infection         1         3  ...          0          0          0
#
# [5 rows x 18 columns]

# %%
d = d.replace('dischromic _patches', 0)
d = d.replace('spotting_ urination',0)
df = d.replace('foul_smell_of urine',0)
df.head()
# Out:
#             Disease  Symptom_1  Symptom_2  ...  Symptom_15  Symptom_16  Symptom_17
# 0  Fungal infection          1          3  ...           0           0           0
# 1  Fungal infection          3          4  ...           0           0           0
# 2  Fungal infection          1          4  ...           0           0           0
# 3  Fungal infection          1          3  ...           0           0           0
# 4  Fungal infection          1          3  ...           0           0           0
#
# [5 rows x 18 columns]

# %%
(df[cols] == 0).all()
# Out:
# Disease       False
# Symptom_1     False
# Symptom_2     False
# Symptom_3     False
# Symptom_4     False
# Symptom_5     False
# Symptom_6     False
# Symptom_7     False
# Symptom_8     False
# Symptom_9     False
# Symptom_10    False
# Symptom_11    False
# Symptom_12    False
# Symptom_13    False
# Symptom_14    False
# Symptom_15    False
# Symptom_16    False
# Symptom_17    False
# dtype: bool

# %%
df['Disease'].value_counts()
# Out:
# Hypoglycemia                               120
# Cervical spondylosis                       120
# Acne                                       120
# Chicken pox                                120
# Paralysis (brain hemorrhage)               120
# Osteoarthristis                            120
# Hepatitis E                                120
# Hepatitis B                                120
# Impetigo                                   120
# Hepatitis C                                120
# AIDS                                       120
# Fungal infection                           120
# Hepatitis D                                120
# Heart attack                               120
# Tuberculosis                               120
# Peptic ulcer diseae                        120
# Dengue                                     120
# Gastroenteritis                            120
# Common Cold                                120
# Hyperthyroidism                            120
# GERD                                       120
# Malaria                                    120
# COVID                                      120
# Typhoid                                    120
# Drug Reaction                              120
# Urinary tract infection                    120
# (vertigo) Paroymsal  Positional Vertigo    120
# Diabetes                                   120
# Hypertension                               120
# hepatitis A                                120
# Jaundice                                   120
# Allergy                                    120
# Migraine                                   120
# Psoriasis                                  120
# Chronic cholestasis                        120
# Alcoholic hepatitis                        120
# Bronchial Asthma                           120
# Pneumonia                                  120
# Arthritis                                  120
# Varicose veins                             120
# Hypothyroidism                             120
# Dimorphic hemmorhoids(piles)               120
# Name: Disease, dtype: int64

# %%
df['Disease'].unique()
# Out:
# array(['Fungal infection', 'Allergy', 'GERD', 'Chronic cholestasis',
#        'Drug Reaction', 'Peptic ulcer diseae', 'AIDS', 'Diabetes',
#        'Gastroenteritis', 'Bronchial Asthma', 'Hypertension', 'Migraine',
#        'Cervical spondylosis', 'Paralysis (brain hemorrhage)', 'Jaundice',
#        'Malaria', 'Chicken pox', 'Dengue', 'Typhoid', 'hepatitis A',
#        'Hepatitis B', 'Hepatitis C', 'Hepatitis D', 'Hepatitis E',
#        'Alcoholic hepatitis', 'Tuberculosis', 'Common Cold', 'Pneumonia',
#        'Dimorphic hemmorhoids(piles)', 'Heart attack', 'Varicose veins',
#        'Hypothyroidism', 'Hyperthyroidism', 'Hypoglycemia',
#        'Osteoarthristis', 'Arthritis',
#        '(vertigo) Paroymsal  Positional Vertigo', 'Acne',
#        'Urinary tract infection', 'Psoriasis', 'Impetigo', 'COVID'],
#       dtype=object)

# %%
data = df.iloc[:,1:].values
labels = df['Disease'].values
data
x_train, x_test, y_train, y_test = train_test_split(data, labels, shuffle=True, train_size = 0.85)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
model = SVC()
model.fit(x_train, y_train)
# Out:
# (4284, 17) (756, 17) (4284,) (756,)
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
preds = model.predict(x_test)
conf_mat = confusion_matrix(y_test, preds)
df_cm = pd.DataFrame(conf_mat, index=df['Disease'].unique(), columns=df['Disease'].unique())
print('F1-score% =', f1_score(y_test, preds, average='macro')*100, '|', 'Accuracy% =', accuracy_score(y_test, preds)*100)


df2= pd.read_csv('/content/Book1.csv')
df2_vals= df2.values
symptoms = df1['Symptom'].unique()

for i in range(len(symptoms)):
    df2_vals[df2_vals == symptoms[i]] = df1[df1['Symptom'] == symptoms[i]]['weight'].values[0]
    df4= symptoms

df2_vals
df3 = pd.DataFrame(df2_vals, columns=cols)
df3.head()
df3 = df3.fillna(0)
data2 = df3.iloc[:,1:].values
data2
disease= model.predict(data2)
disease
# Out:
# F1-score% = 92.90978667205452 | Accuracy% = 92.98941798941799
# array(['Chicken pox', 'Diabetes', 'Gastroenteritis', 'COVID'],
#       dtype=object)

# %%
# !pip install googletrans
# Out:
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.5 MB/s
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2.10)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting hstspreload
#   Downloading hstspreload-2021.9.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 37.1 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2021.5.30)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.4 MB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.2 MB/s
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.7 MB/s
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15734 sha256=d345482b756df4c7708810a566c7f4876e2adc9579b734caab13cda86222ad6c
#   Stored in directory: /root/.cache/pip/wheels/20/da/eb/a54579056f265eede0417df537dd56d3df5b9eb2b25df0003d
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.9.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0

# %%
# !pip install pickle-mixin
# !pip install tensorflow
# !pip install tflearn
# !pip install nltk
# Out:
# Requirement already satisfied: pickle-mixin in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.6.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (5.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.40.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.6.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.5.0)
# Requirement already satisfied: tflearn in /usr/local/lib/python3.7/dist-packages (0.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tflearn) (1.19.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from tflearn) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tflearn) (1.15.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.6.0)

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('Disease_intents.json').read()
intents = json.loads(data_file)
intents
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# {'intents': [{'patterns': ['I have fever',
#     'What should I do if I have fever',
#     'I am feeling feversih',
#     'fever'],
#    'responses': [{'options': ["I haven't checked",
#       'Above 100 degree F',
#       'Below 100 degree F'],
#      'question': ['What is your body Temperature?']},
#     {'options': ['It is manageable', 'It is really bad'],
#      'question': ['How bad is the fever?']}],
#    'tag': 'fever'},
#   {'patterns': ['I have headache',
#     'What should I do if I have headache',
#     'I am feeling a really bad headache',
#     'headache'],
#    'responses': [{'options': ['It is manageable', 'It is really bad'],
#      'question': ['How bad is the headache?']},
#     {'options': ['Yes', 'No'],
#      'question': ['Did you get any sort of injury on your head?']},
#     {'options': ['Yes', 'No'],
#      'question': ['Are you going through some sort of stress?']}],
#    'tag': 'headache'},
#   {'patterns': ['I am vomiting',
#     'I have continuous vomiting',
#     'I keep vomiting',
#     'vomit',
#     'I feel like vommiting'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['Since how many days are you feeling like vomiting?']}],
#    'tag': 'vomiting'},
#   {'patterns': ['I have abdominal pain',
#     'What should I do if I have abdominal pain',
#     'I am feeling pain in my abdomen',
#     'pain in abdomen',
#     'abdominal pain'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['Since how many days are you feeling pain your abdomen?']},
#     {'options': ['It is manageable', 'It is really bad'],
#      'question': ['How bad is the pain?']}],
#    'tag': 'abdominal_pain'},
#   {'patterns': ['I am feeling itchy',
#     'I am getting an itching sensation',
#     'my body is itchy',
#     'itchy',
#     'itching'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['Since how many days are you feeling itchy?']}],
#    'tag': 'itching'},
#   {'patterns': ['I am having a skin rash',
#     'I got a rash',
#     'skin rash',
#     'rash',
#     'rash on my skin'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['When did you get this rash?']},
#     {'options': ['It is bad', 'It is really worse', 'It is manageable'],
#      'question': ['How bad is the rash?']}],
#    'tag': 'skin_rash'},
#   {'patterns': ['I am having a skin eruptions',
#     'I am having a skin eruption',
#     'skin eruptions',
#     'skin eruption',
#     'nodal skin eruptions',
#     'nodal skin eruption'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['When did your skin started erupting?']}],
#    'tag': 'nodal_skin_eruptions'},
#   {'patterns': ['I am having dyschromia',
#     'I am having a patches on my body',
#     'dyschromia',
#     'dischromic patches',
#     'patches',
#     'patches on my skin'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['When did you get those patches?']}],
#    'tag': 'dischromic_patches'},
#   {'patterns': ['I am sneezing continuously',
#     'sneezing continuously',
#     'continuous sneezing'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['Since how many days are you sneezing?']}],
#    'tag': 'continuous_sneezing'},
#   {'patterns': ['I am shivering', 'shivering'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['When did you start experiencing this symptom?']}],
#    'tag': 'shivering'},
#   {'patterns': ['I am experiencing chills', 'chills'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['When did you start experiencing this symptom?']},
#     {'options': ['It is really worse', 'It is manageable'],
#      'question': ['How bad are these chills?']}],
#    'tag': 'chills'},
#   {'patterns': ['watering from eyes', 'eyes are watering', 'watery eyes'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['When did you start experiencing this symptom?']}],
#    'tag': 'watering_from_eyes'},
#   {'patterns': ['stomach pain', 'pain in my stomach'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['When did the pain start?']},
#     {'options': ['It is really worse', 'It is manageable'],
#      'question': ['How bad is the pain?']}],
#    'tag': 'stomach_pain'},
#   {'patterns': ['having acidity',
#     'acidity',
#     'feeling like acidity',
#     'feel like acidity',
#     'feeling of acidity'],
#    'responses': [{'options': ['In the night after eating food',
#       'In the night before eating food',
#       'In the morning before eating food',
#       'In the morning after eating food'],
#      'question': ['When do you experience this symptom?']}],
#    'tag': 'acidity'},
#   {'patterns': ['I have ulcers on my tongue', 'ulcers on tongue'],
#    'responses': [{'options': ['yesterday',
#       'It has been More than one day',
#       'today'],
#      'question': ['When did you get ulcers?']},
#     {'options': ['It is really worse', 'It is manageable'],
#      'question': ['How bad is the ulcer?']}],
#    'tag': ' ulcers_on_tongue'},
#   {'patterns': ['cough'],
#    'responses': [{'options': ['yesterday',
#       'It has been More than one day',
#       'today'],
#      'question': ['Since how many days have you been coughing?']},
#     {'options': ['Yes', 'No'],
#      'question': ['Do you feel pain in the chest while coughing?']}],
#    'tag': 'cough'},
#   {'patterns': ['cough'],
#    'responses': [{'options': ['since yesterday',
#       'More than one day',
#       'since today'],
#      'question': ['When did the pain start?']},
#     {'options': ['It is really worse', 'It is manageable'],
#      'question': ['How bad is the pain?']}],
#    'tag': 'chest_pain'},
#   {'patterns': ['skin turned to yellow',
#     'yellowish skin',
#     'skin turned to pail yellow'],
#    'responses': [{'options': ['yesterday',
#       'It has been More than one day',
#       'today'],
#      'question': ['When did your skin turned yellow?']}],
#    'tag': 'yellowish_skin'},
#   {'patterns': ['nausea'],
#    'responses': [{'options': ['Since yesterday',
#       'It has been More than one day',
#       'today'],
#      'question': ['When did you start experiencing nausea?']}],
#    'tag': 'nausea'},
#   {'patterns': ['loss of appetite', 'dont feel like eating food'],
#    'responses': [{'options': ['Yes', 'No', 'Sometimes'],
#      'question': ['Are you feeling like not eating food at all?']},
#     {'options': ['Since yesterday', 'It has been More than one day', 'today'],
#      'question': ['Since How many days are you feeling like not eating food?']}],
#    'tag': ' loss_of_appetite'},
#   {'patterns': ['eyes turned to yellow', 'yellowing of eyes'],
#    'responses': [{'options': ['yesterday',
#       'It has been More than one day',
#       'today'],
#      'question': ['When did your eyes turned to yellow?']}],
#    'tag': ' yellowing_of_eyes'}]}

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        print(words)
        #add documents in the corpus
        documents.append((w, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# Out:
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation']
# ...
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow']
# ['I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes', 'I', 'have', 'fever', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'fever', 'I', 'am', 'feeling', 'feversih', 'fever', 'I', 'have', 'headache', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'headache', 'I', 'am', 'feeling', 'a', 'really', 'bad', 'headache', 'headache', 'I', 'am', 'vomiting', 'I', 'have', 'continuous', 'vomiting', 'I', 'keep', 'vomiting', 'vomit', 'I', 'feel', 'like', 'vommiting', 'I', 'have', 'abdominal', 'pain', 'What', 'should', 'I', 'do', 'if', 'I', 'have', 'abdominal', 'pain', 'I', 'am', 'feeling', 'pain', 'in', 'my', 'abdomen', 'pain', 'in', 'abdomen', 'abdominal', 'pain', 'I', 'am', 'feeling', 'itchy', 'I', 'am', 'getting', 'an', 'itching', 'sensation', 'my', 'body', 'is', 'itchy', 'itchy', 'itching', 'I', 'am', 'having', 'a', 'skin', 'rash', 'I', 'got', 'a', 'rash', 'skin', 'rash', 'rash', 'rash', 'on', 'my', 'skin', 'I', 'am', 'having', 'a', 'skin', 'eruptions', 'I', 'am', 'having', 'a', 'skin', 'eruption', 'skin', 'eruptions', 'skin', 'eruption', 'nodal', 'skin', 'eruptions', 'nodal', 'skin', 'eruption', 'I', 'am', 'having', 'dyschromia', 'I', 'am', 'having', 'a', 'patches', 'on', 'my', 'body', 'dyschromia', 'dischromic', 'patches', 'patches', 'patches', 'on', 'my', 'skin', 'I', 'am', 'sneezing', 'continuously', 'sneezing', 'continuously', 'continuous', 'sneezing', 'I', 'am', 'shivering', 'shivering', 'I', 'am', 'experiencing', 'chills', 'chills', 'watering', 'from', 'eyes', 'eyes', 'are', 'watering', 'watery', 'eyes', 'stomach', 'pain', 'pain', 'in', 'my', 'stomach', 'having', 'acidity', 'acidity', 'feeling', 'like', 'acidity', 'feel', 'like', 'acidity', 'feeling', 'of', 'acidity', 'I', 'have', 'ulcers', 'on', 'my', 'tongue', 'ulcers', 'on', 'tongue', 'cough', 'cough', 'skin', 'turned', 'to', 'yellow', 'yellowish', 'skin', 'skin', 'turned', 'to', 'pail', 'yellow', 'nausea', 'loss', 'of', 'appetite', 'dont', 'feel', 'like', 'eating', 'food', 'eyes', 'turned', 'to', 'yellow', 'yellowing', 'of', 'eyes']

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
type(classes)
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 138 documents
# 21 classes [' loss_of_appetite', ' ulcers_on_tongue', ' yellowing_of_eyes', 'abdominal_pain', 'acidity', 'chest_pain', 'chills', 'continuous_sneezing', 'cough', 'dischromic_patches', 'fever', 'headache', 'itching', 'nausea', 'nodal_skin_eruptions', 'shivering', 'skin_rash', 'stomach_pain', 'vomiting', 'watering_from_eyes', 'yellowish_skin']
# 71 unique lemmatized words ['a', 'abdomen', 'abdominal', 'acidity', 'am', 'an', 'appetite', 'are', 'bad', 'body', 'chill', 'continuous', 'continuously', 'cough', 'dischromic', 'do', 'dont', 'dyschromia', 'eating', 'eruption', 'experiencing', 'eye', 'feel', 'feeling', 'fever', 'feversih', 'food', 'from', 'getting', 'got', 'have', 'having', 'headache', 'i', 'if', 'in', 'is', 'itching', 'itchy', 'keep', 'like', 'loss', 'my', 'nausea', 'nodal', 'of', 'on', 'pail', 'pain', 'patch', 'rash', 'really', 'sensation', 'shivering', 'should', 'skin', 'sneezing', 'stomach', 'to', 'tongue', 'turned', 'ulcer', 'vomit', 'vomiting', 'vommiting', 'watering', 'watery', 'what', 'yellow', 'yellowing', 'yellowish']

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model created")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 28/28 [==============================] - 1s 1ms/step - loss: 3.0216 - accuracy: 0.0580
# Epoch 2/200
# 28/28 [==============================] - 0s 1ms/step - loss: 2.8452 - accuracy: 0.1739
# Epoch 3/200
# 28/28 [==============================] - 0s 3ms/step - loss: 2.6824 - accuracy: 0.2174
# Epoch 4/200
# 28/28 [==============================] - 0s 1ms/step - loss: 2.4166 - accuracy: 0.3116
# Epoch 5/200
# 28/28 [==============================] - 0s 2ms/step - loss: 2.1952 - accuracy: 0.3551
# Epoch 6/200
# 28/28 [==============================] - 0s 2ms/step - loss: 1.9489 - accuracy: 0.4710
# Epoch 7/200
# 28/28 [==============================] - 0s 2ms/step - loss: 1.6101 - accuracy: 0.5870
# Epoch 8/200
# 28/28 [==============================] - 0s 2ms/step - loss: 1.4743 - accuracy: 0.5725
# Epoch 9/200
# 28/28 [==============================] - 0s 2ms/step - loss: 1.3603 - accuracy: 0.5580
# Epoch 10/200
# 28/28 [==============================] - 0s 2ms/step - loss: 1.1614 - accuracy: 0.6884
# Epoch 11/200
# 28/28 [==============================] - 0s 2ms/step - loss: 1.0105 - accuracy: 0.7464
# Epoch 12/200
# 28/28 [==============================] - 0s 2ms/step - loss: 1.0192 - accuracy: 0.7101
# Epoch 13/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7403 - accuracy: 0.8188
# Epoch 14/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7105 - accuracy: 0.7899
# Epoch 15/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6383 - accuracy: 0.8116
# Epoch 16/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7606 - accuracy: 0.7899
# Epoch 17/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5839 - accuracy: 0.8478
# Epoch 18/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3985 - accuracy: 0.9203
# Epoch 19/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.9275
# Epoch 20/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8986
# Epoch 21/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.8841
# Epoch 22/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2917 - accuracy: 0.9493
# Epoch 23/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3250 - accuracy: 0.9348
# Epoch 24/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3530 - accuracy: 0.9058
# Epoch 25/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3204 - accuracy: 0.8986
# Epoch 26/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2853 - accuracy: 0.9130
# Epoch 27/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2520 - accuracy: 0.9348
# Epoch 28/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.9420
# Epoch 29/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2721 - accuracy: 0.9058
# Epoch 30/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2066 - accuracy: 0.9493
# Epoch 31/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2424 - accuracy: 0.9203
# Epoch 32/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2305 - accuracy: 0.9420
# Epoch 33/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2115 - accuracy: 0.9275
# Epoch 34/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9348
# Epoch 35/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2181 - accuracy: 0.9493
# Epoch 36/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2026 - accuracy: 0.9348
# Epoch 37/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1676 - accuracy: 0.9493
# Epoch 38/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2064 - accuracy: 0.9130
# Epoch 39/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1967 - accuracy: 0.9493
# Epoch 40/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1835 - accuracy: 0.9565
# Epoch 41/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1826 - accuracy: 0.9638
# Epoch 42/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1294 - accuracy: 0.9783
# Epoch 43/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1485 - accuracy: 0.9710
# Epoch 44/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1486 - accuracy: 0.9783
# Epoch 45/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1398 - accuracy: 0.9420
# Epoch 46/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1546 - accuracy: 0.9565
# Epoch 47/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1330 - accuracy: 0.9710
# Epoch 48/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.9565
# Epoch 49/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1825 - accuracy: 0.9348
# Epoch 50/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1364 - accuracy: 0.9565
# Epoch 51/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0924 - accuracy: 0.9855
# Epoch 52/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9710
# Epoch 53/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1505 - accuracy: 0.9493
# Epoch 54/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1991 - accuracy: 0.9275
# Epoch 55/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1626 - accuracy: 0.9348
# Epoch 56/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0957 - accuracy: 0.9638
# Epoch 57/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1169 - accuracy: 0.9638
# Epoch 58/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1438 - accuracy: 0.9420
# Epoch 59/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9710
# Epoch 60/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.9638
# Epoch 61/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1005 - accuracy: 0.9565
# Epoch 62/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1339 - accuracy: 0.9565
# Epoch 63/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1305 - accuracy: 0.9493
# Epoch 64/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1262 - accuracy: 0.9638
# Epoch 65/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1102 - accuracy: 0.9638
# Epoch 66/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0685 - accuracy: 0.9783
# Epoch 67/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9783
# Epoch 68/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.9638
# Epoch 69/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 0.9928
# Epoch 70/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0674 - accuracy: 0.9710
# Epoch 71/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9855
# Epoch 72/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.9565
# Epoch 73/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9928
# Epoch 74/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.9783
# Epoch 75/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.9565
# Epoch 76/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9638
# Epoch 77/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0849 - accuracy: 0.9710
# Epoch 78/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1015 - accuracy: 0.9638
# Epoch 79/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.9565
# Epoch 80/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1106 - accuracy: 0.9493
# Epoch 81/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1029 - accuracy: 0.9565
# Epoch 82/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0641 - accuracy: 0.9783
# Epoch 83/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0783 - accuracy: 0.9783
# Epoch 84/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0843 - accuracy: 0.9710
# Epoch 85/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0718 - accuracy: 0.9565
# Epoch 86/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0755 - accuracy: 0.9710
# Epoch 87/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9710
# Epoch 88/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0711 - accuracy: 0.9783
# Epoch 89/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9710
# Epoch 90/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0638 - accuracy: 0.9783
# Epoch 91/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1338 - accuracy: 0.9493
# Epoch 92/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9855
# Epoch 93/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.9783
# Epoch 94/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.9710
# Epoch 95/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0559 - accuracy: 0.9855
# Epoch 96/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 0.9710
# Epoch 97/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0561 - accuracy: 0.9855
# Epoch 98/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 0.9855
# Epoch 99/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0864 - accuracy: 0.9710
# Epoch 100/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0896 - accuracy: 0.9638
# Epoch 101/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0659 - accuracy: 0.9928
# Epoch 102/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1154 - accuracy: 0.9565
# Epoch 103/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.9638
# Epoch 104/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9565
# Epoch 105/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0761 - accuracy: 0.9710
# Epoch 106/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 0.9928
# Epoch 107/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0546 - accuracy: 0.9928
# Epoch 108/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9710
# Epoch 109/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0657 - accuracy: 0.9855
# Epoch 110/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 0.9638
# Epoch 111/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1001 - accuracy: 0.9638
# Epoch 112/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0439 - accuracy: 0.9855
# Epoch 113/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1151 - accuracy: 0.9565
# Epoch 114/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9638
# Epoch 115/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1159 - accuracy: 0.9493
# Epoch 116/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0928 - accuracy: 0.9493
# Epoch 117/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.9638
# Epoch 118/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 0.9638
# Epoch 119/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0786 - accuracy: 0.9638
# Epoch 120/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.9855
# Epoch 121/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.9638
# Epoch 122/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1152 - accuracy: 0.9638
# Epoch 123/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0528 - accuracy: 0.9855
# Epoch 124/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9638
# Epoch 125/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1016 - accuracy: 0.9565
# Epoch 126/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0614 - accuracy: 0.9783
# Epoch 127/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9855
# Epoch 128/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0444 - accuracy: 0.9783
# Epoch 129/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9855
# Epoch 130/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 0.9928
# Epoch 131/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0906 - accuracy: 0.9565
# Epoch 132/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0781 - accuracy: 0.9638
# Epoch 133/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0867 - accuracy: 0.9710
# Epoch 134/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9783
# Epoch 135/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9855
# Epoch 136/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0423 - accuracy: 0.9783
# Epoch 137/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1037 - accuracy: 0.9565
# Epoch 138/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9855
# Epoch 139/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 0.9855
# Epoch 140/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9638
# Epoch 141/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 0.9638
# Epoch 142/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0680 - accuracy: 0.9638
# Epoch 143/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 0.9638
# Epoch 144/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9855
# Epoch 145/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0651 - accuracy: 0.9783
# Epoch 146/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0530 - accuracy: 0.9783
# Epoch 147/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0933 - accuracy: 0.9565
# Epoch 148/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9565
# Epoch 149/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9638
# Epoch 150/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0443 - accuracy: 0.9855
# Epoch 151/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 0.9783
# Epoch 152/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0637 - accuracy: 0.9855
# Epoch 153/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0492 - accuracy: 0.9855
# Epoch 154/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0768 - accuracy: 0.9638
# Epoch 155/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.9710
# Epoch 156/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.9565
# Epoch 157/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.9565
# Epoch 158/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0930 - accuracy: 0.9565
# Epoch 159/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0684 - accuracy: 0.9710
# Epoch 160/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9638
# Epoch 161/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9928
# Epoch 162/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9638
# Epoch 163/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1231 - accuracy: 0.9565
# Epoch 164/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0784 - accuracy: 0.9565
# Epoch 165/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0744 - accuracy: 0.9565
# Epoch 166/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0791 - accuracy: 0.9638
# Epoch 167/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9710
# Epoch 168/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0463 - accuracy: 0.9783
# Epoch 169/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0605 - accuracy: 0.9710
# Epoch 170/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0879 - accuracy: 0.9565
# Epoch 171/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9855
# Epoch 172/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9783
# Epoch 173/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0473 - accuracy: 0.9928
# Epoch 174/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9855
# Epoch 175/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 0.9783
# Epoch 176/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 0.9928
# Epoch 177/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0591 - accuracy: 0.9710
# Epoch 178/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9638
# Epoch 179/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.9638
# Epoch 180/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0568 - accuracy: 0.9855
# Epoch 181/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 0.9783
# Epoch 182/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0444 - accuracy: 0.9855
# Epoch 183/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0530 - accuracy: 0.9783
# Epoch 184/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0682 - accuracy: 0.9638
# Epoch 185/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0480 - accuracy: 0.9855
# Epoch 186/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.9783
# Epoch 187/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0535 - accuracy: 0.9710
# Epoch 188/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0625 - accuracy: 0.9783
# Epoch 189/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0535 - accuracy: 0.9710
# Epoch 190/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9855
# Epoch 191/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9783
# Epoch 192/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0529 - accuracy: 0.9783
# Epoch 193/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 0.9855
# Epoch 194/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0540 - accuracy: 0.9783
# Epoch 195/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 0.9855
# Epoch 196/200
# 28/28 [==============================] - 0s 1ms/step - loss: 0.0744 - accuracy: 0.9638
# Epoch 197/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 0.9928
# Epoch 198/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0445 - accuracy: 0.9928
# Epoch 199/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0864 - accuracy: 0.9710
# Epoch 200/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0468 - accuracy: 0.9855
# model created

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    result_question=[]
    result_option=[] 
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = i['responses']
            for j in range(0,len(result)):
              result_question.append(result[j]['question'])
              result_option.append(result[j]['options'])
            print(result_question[0])
            print(result_option[0][1])
            break

    return result_question,result_option
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
msg=input("Enter the text: ")
result_ques,result_opt= chatbot_response(msg)
print(result_ques[0])
# Out:
# Enter the text: chills
# ['When did you start experiencing this symptom?']
# More than one day
# ['When did you start experiencing this symptom?']
